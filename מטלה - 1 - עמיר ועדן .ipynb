# %% [markdown]
# ---
# ## mtala 1 solution:
# ### name of students:
#
# עמיר פאעור תז 316540467
#
# עדן דוקצייב תז 316365733

# %% [markdown]
# ---
# Open the folder numpy and panda so i can use there functions

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ---
# solution to question 1:

# %% [markdown]
# opening the file and saving it in vac_file so i can do the function on it
# i can use print and i can do it without print function and Jupyter show it in a better way
# the defult numbers of lines for the head function is 5 , so i can write head without number 5

# %%
vac_file=pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')

# %%
vac_file.head(5)
# Out:
#   location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# ---
# solution to question 2:
# checking if the all the detailes that contain the word Argentina in the cloumn location

# %%
Argentina=vac_file[vac_file["location"].str.contains("Argentina")]
Argentina
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 184  Argentina      ARG  2020-12-29               700.0                NaN
# 185  Argentina      ARG  2020-12-30                 NaN                NaN
# 186  Argentina      ARG  2020-12-31             32013.0                NaN
# 187  Argentina      ARG  2021-01-01                 NaN                NaN
# 188  Argentina      ARG  2021-01-02                 NaN                NaN
# ..         ...      ...         ...                 ...                ...
# 256  Argentina      ARG  2021-03-11           1919074.0          1564555.0
# 257  Argentina      ARG  2021-03-12           2098205.0          1719543.0
# 258  Argentina      ARG  2021-03-13           2294738.0          1876113.0
# 259  Argentina      ARG  2021-03-14           2381429.0          1932696.0
# 260  Argentina      ARG  2021-03-15           2404194.0          1952883.0
#
# ...

# %% [markdown]
# ---
# solution to question 3:
# Showing the length of all the rows that contain the word Argentina in the cloumn location

# %%
Argentina_Len=len(Argentina)
Argentina_Len
# Out:
# 77

# %% [markdown]
# ---
# solution to question 4:
# Saving the index of the daily vaccinations max value and then showing the date

# %%
mostVacc=Argentina["daily_vaccinations"].idxmax()
vac_file["date"][mostVacc]
# Out:
# '2021-03-15'

# %% [markdown]
# ---
# solution to question 5:
# First i saved the first 3 rows (Argentina country) and then i chose only a 3 columns

# %%
Rows=(Argentina).head(3)
threeOnly=Rows[["location","daily_vaccinations","date"]]
threeOnly
# Out:
#       location  daily_vaccinations        date
# 184  Argentina                 NaN  2020-12-29
# 185  Argentina             15656.0  2020-12-30
# 186  Argentina             15656.0  2020-12-31

# %% [markdown]
# ---
# solution to question 6:
# Using mean function on the Argentina daily vaccinations to know the avrage (with skiping the nan)

# %%
avrage_DailyVacc=Argentina["daily_vaccinations"].mean(skipna = True) 
avrage_DailyVacc
# Out:
# 27782.38157894737

# %% [markdown]
# ---
# solution to question 7:
# dropna() function is removing all the empty values

# %%
droping_all_nan=Argentina[["people_vaccinated_per_hundred"]].dropna()
droping_all_nan
# Out:
#      people_vaccinated_per_hundred
# 206                           0.54
# 207                           0.55
# 208                           0.56
# 209                           0.57
# 210                           0.58
# 211                           0.58
# 212                           0.59
# 213                           0.60
# 214                           0.61
# 215                           0.62
# 216                           0.62
# 218                           0.62
# 220                           0.63
# 221                           0.66
# 223                           0.68
# 224                           0.71
# 225                           0.71
# 226                           0.71
# 227                           0.75
# 228                           0.80
# 229                           0.81
# 230                           0.82
# 231                           0.82
# 232                           0.82
# 233                           0.83
# 234                           0.83
# ...

# %% [markdown]
# ---
# solution to question 8:
# using mean to do ave and skip the nan values

# %%
avrage_without_nan=Argentina["people_vaccinated_per_hundred"].mean(skipna=True) 
avrage_without_nan
# Out:
# 1.4023529411764708

# %% [markdown]
# ---
# solution to question 8:
# making an if statemean that checks what is greater

# %%
if Argentina["daily_vaccinations"].median() > avrage_DailyVacc:
    print("the median is bigger than the average (mean function)")
else:
    print("the average (mean function) is bigger than the median")
# Out:
# the average (mean function) is bigger than the median
